# %%
#q6 - Given a sentance ,display the frequency of every character.
sentence = input("Enter a sentence: ")
freq = {}
for ch in sentence:
    if ch in freq:
        freq[ch] += 1
    else:
        freq[ch] = 1
print(freq)
# Out:
# Enter a sentence:  My name is Bibek
# {'M': 1, 'y': 1, ' ': 3, 'n': 1, 'a': 1, 'm': 1, 'e': 2, 'i': 2, 's': 1, 'B': 1, 'b': 1, 'k': 1}

# %%
#q7- Remove duplicate roll numbers while preserving the original order.
roll = [20,21,34,55,43,32,20,21]
s_roll=set(roll)
print(s_roll)
# Out:
# {32, 34, 43, 20, 21, 55}

# %%
#q8 - Store Monthly rainfall values and print rainfall of the last three months
rainfall = [120, 95, 110, 130, 125, 140, 150, 145, 135, 160, 155, 170]
print("Rainfall of Last Three Months:")
print(rainfall[-3:])
# Out:
# Rainfall of Last Three Months:
# [160, 155, 170]

# %%
#q9- Maintain a simple contact directory supporting search by name.
contacts = {
    "Deba": "9876543210",
    "Govind": "9876501234",
    "Suraj": "9123456789"
}
name = input("Enter name to search: ")
if name in contacts:
    print("Phone Number:", contacts[name])
else:
    print("Not found")
# Out:
# Enter name to search:  Deba
# Phone Number: 9876543210

# %%
#q10 - Given marks of students ,print names of studenets scoring above class average.
students = {
    "Ritik": 80,
    "Sagar": 70,
    "Sahil": 90,
    "Naveen": 60
}
average = sum(students.values()) / len(students)
print("Class Average:", average)

print("Students Scoring Above Average:")
for name, marks in students.items():
    if marks > average:
        print(name)
# Out:
# Class Average: 75.0
# Students Scoring Above Average:
# Ritik
# Sahil

# %%
#q31 - Design a mini socail media data model supporting friends,mutual friends and friends suggestions.

friends = {
    "Rohit": {"Arman", "Riya", "Neha"},
    "Arman": {"Rohit", "Riya", "Karan"}
}
print("Friends:", friends["Rohit"])

print("Mutual Friends:", friends["Rohit"] & friends["Arman"])
print("Friend Suggestions:", friends["Arman"] - friends["Rohit"] - {"Rohit"})
# Out:
# Friends: {'Riya', 'Arman', 'Neha'}
# Mutual Friends: {'Riya'}
# Friend Suggestions: {'Karan'}

# %%
#q32 - Build a recommendation engine that suggest products purchased by simmilar customers and not bt the current customer

# %%
#q33 - Createa airline reservation model and detect double booked seats

# %%
#q34 - Develop an online coding contest scoreboard supporting rank updates after every submission.

# %%
#q35 - Build a plagiarism checker that compare ]s two assignments based on unique woeds and similarity percentage

# %%
#Exception handling

# %%
#Handle Division by Zero
try:
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    print("Result =", a / b)

except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Enter numerator:  10
# Enter denominator:  0
# Cannot divide by zero.

# %%
#Handle Invalid Age Input
try:
    age = int(input("Enter age: "))

    if age < 0:
        raise ValueError("Age cannot be negative.")

    print("Age:", age)

except ValueError as e:
    print(e)
# Out:
# Enter age:  -2
# Age cannot be negative.

# %%
#Handle List Index Error
numbers = [10, 20, 30]

try:
    index = int(input("Enter index: "))
    print(numbers[index])

except IndexError:
    print("Invalid index.")
# Out:
# Enter index:  2
# 30

# %%
#Handle dictionary key error 
student = {
    "name": "Rahul",
    "age": 20
}

try:
    key = input("Enter key: ")
    print(student[key])

except KeyError:
    print("Key not found.")
# Out:
# Enter key:  Class
# Key not found.

# %%
#Handle File Not Found
try:
    file = open("data.txt", "r")
    print(file.read())

except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
#Calculate using try catch
